# %%
import pandas as pd
import string
import zeyrek

#Easier reading
pd.set_option('display.max_colwidth',None)
#Twitter dataset (one month)
twit_jan20_DF = pd.read_csv("jan20.csv", sep=";", header=None)
#Transpose
twit_jan20_DFT = twit_jan20_DF.T
#twit_jan20_DFT.describe()

#ANEW Turkish dataset
anew_turkish = pd.read_excel("ANEW_Turkish.xlsx",sheet_name="Sheet1")
#column addition
anew_turkish.columns = ["isimler", "ing-karsiligi", "valence", "arousal", "dominance", "etiketler"]

#lemmatization object
analyzer = zeyrek.MorphAnalyzer()

#Good ol' mean, but does not cry when it is empty
def get_mean(alist):
    if len(alist) == 0:
        return 0
    return sum(alist)/len(alist)

#Ignores the zeros in the list
def get_mean_twit(alist):
    modded_length = 0
    for i in range(len(alist)):
        if alist[i] != 0:
            modded_length += 1
    return sum(alist)/modded_length

#This function takes a string (a Twit), lemmatize it, then assign statistical value of each word if it exists in ANEW dictionary.
def nlp_operations_VAD(a_twit):
    
    #Getting input twit
    string1 = str(a_twit)
    #Lowercase it
    string1 = string1.lower()
    #Split it (or call it tokenizing)
    split1 = [i for i in string1.split(' ')]

    t1 = []
    #This lemmatizes the words in the string
    for i in range(len(split1)):
        t1.append(analyzer.lemmatize(split1[i]))

    #creating lists for valence, arousal and dominance values' mean, so that row of twit can have these values    
    t1_V, t1_A, t1_D = [], [], []
    
    
    #iterate over list that holds the lemmatized words
    for i in range(len(t1)): 
        #iterate over lemmatization tuples
        for words in t1[i][0]:
            #Lemmas can be more than one so getting mean of interpretations could be useful.
            word_sum_V, word_sum_A, word_sum_D = [], [], []

            #Lemmtization products are in a list, take it by itself
            if type(words) == list:
                for i in words:
                    if (anew_turkish["isimler"] == i).any():
                        word_sum_V.append(anew_turkish.loc[anew_turkish["isimler"] == i]["valence"].iloc[0])
                        word_sum_A.append(anew_turkish.loc[anew_turkish["isimler"] == i]["arousal"].iloc[0])
                        word_sum_D.append(anew_turkish.loc[anew_turkish["isimler"] == i]["dominance"].iloc[0])

            #Just string, which is the word without lemmazitaion
            elif type(words) == str:

                if (anew_turkish["isimler"] == i).any():
                    word_sum_V.append(anew_turkish.loc[anew_turkish["isimler"] == i]["valence"].iloc[0])
                    word_sum_A.append(anew_turkish.loc[anew_turkish["isimler"] == i]["arousal"].iloc[0])
                    word_sum_D.append(anew_turkish.loc[anew_turkish["isimler"] == i]["dominance"].iloc[0])

            #Bunch up the words in mean to twit part.
            t1_V.append(get_mean(word_sum_V))
            t1_A.append(get_mean(word_sum_A))
            t1_D.append(get_mean(word_sum_D))


    return [round(get_mean_twit(t1_V), 2), round(get_mean_twit(t1_A), 2), round(get_mean_twit(t1_D), 2)]

# %%
#Some info
twit_jan20_DFT.describe()
twit_jan20_DFT.head(10)
anew_turkish.describe()
# Out:
#             valence       arousal     dominance
# count  15218.000000  15218.000000  15218.000000
# mean       3.053836      2.603538      3.113214
# std        0.652980      0.445302      0.482177
# min        1.130000      1.340000      1.340000
# 25%        2.630000      2.290000      2.810000
# 50%        3.130000      2.550000      3.160000
# 75%        3.500000      2.870000      3.450000
# max        4.770000      4.400000      4.430000

# %%
#Add Twits column name
twit_jan20_DFT.columns = ["Twits"]
twit_jan20_DFT.head(5)
# Out:
#                                                                                                                                                 Twits
# 0                                                                                  7 bin kişilik gemide Korona virüsü şüphesi https://t.co/whdJ45XrOW
# 1                                                          7 bin kişilik gemide Korona virüsü şüphesi https://t.co/ZCIoZNrf0X https://t.co/b6QWOIP39R
# 2  RT @SunaVarol_: Dünya Sağlık Örgütü korona virüsü için acil durum ilan etti.\r\n\r\nKorona Virüsü için alınan tedbirler araştırılsın önergesi AKP…
# 3     RT @TK_HelpDesk: ℹ\r\nKorona Virüsü kaynaklı durumu ve son gelişmeleri ulusal ve uluslararası otoritelerle değerlendirmek için; Pekin, Guangzh…
# 4                                                            Çin’de korona virüs vakası nedeniyle ölü sayısı 170’e yükseldi.. https://t.co/SLKl7Xfduf

# %%
#Some textual preprocessing
df1 = twit_jan20_DFT
df1['Twits'] = df1['Twits'].astype("string")
df1['Twits'] = df1['Twits'].str.replace('@[A-Za-z0-9]+','')
df1['Twits'] = df1['Twits'].str.replace('http\S+','')
df1['Twits'] = df1['Twits'].str.replace('[^\w\s]+','')
df1['Twits'] = df1['Twits'].str.replace(' +', ' ')
#df1['TWits'] = df1['Twits'].str.replace('\r\n')
df1["Twits"] = df1["Twits"].str.strip()

df1["Valence"] = None
df1["Arousal"] = None
df1["Dominance"] = None
df1
# Out:
# <ipython-input-55-ace7b47753a4>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Twits'] = df1['Twits'].str.replace('@[A-Za-z0-9]+','')
# <ipython-input-55-ace7b47753a4>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Twits'] = df1['Twits'].str.replace('http\S+','')
# <ipython-input-55-ace7b47753a4>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Twits'] = df1['Twits'].str.replace('[^\w\s]+','')
# <ipython-input-55-ace7b47753a4>:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Twits'] = df1['Twits'].str.replace(' +', ' ')
#                                                                                                                                           Twits  \
# 0                                                                                                    7 bin kişilik gemide Korona virüsü şüphesi
# 1                                                                                                    7 bin kişilik gemide Korona virüsü şüphesi
# 2             RT _ Dünya Sağlık Örgütü korona virüsü için acil durum ilan etti
#
# Korona Virüsü için alınan tedbirler araştırılsın önergesi AKP
# 3        RT _HelpDesk ℹ
# Korona Virüsü kaynaklı durumu ve son gelişmeleri ulusal ve uluslararası otoritelerle değerlendirmek için Pekin Guangzh
# 4                                                                                  Çinde korona virüs vakası nedeniyle ölü sayısı 170e yükseldi
# ..                                                                                                                                          ...
# 95                                         RT SONDAKİKA
#
# Korona Virusü nedeniyle ölenlerin sayısı 213e yükseldi
#
# Coronavirus
# Wuhan
# China
# 96       RT _HelpDesk ℹ
# Korona Virüsü kaynaklı durumu ve son gelişmeleri ulusal ve uluslararası otoritelerle değerlendirmek için Pekin Guangzh
# 97  RT _alim65 Çinde
# Vatandaşlarını Çinden çekiyor
#
#  Korona virüsünün yayılması nedeniyle
#
# bence
#  Vatandaşlarına
#
# Soğan ve sarımsak yi
# 98                                                             Yeni tip diye bahsettikleri şu anki zaten Daha önce 2 farklı korona virüsü vardı
# 99            RT _ Dünya Sağlık Örgütü korona virüsü için acil durum ilan etti
#
# Korona Virüsü için alınan tedbirler araştırılsın önergesi AKP
#
#    Valence Arousal Dominance
# 0     None    None      None
# 1     None    None      None
# 2     None    None      None
# 3     None    None      None
# 4     None    None      None
# ..     ...     ...       ...
# 95    None    None      None
# 96    None    None      None
# 97    None    None      None
# 98    None    None      None
# 99    None    None      None
#
# [100 rows x 4 columns]

# %%
for idx in range(df1.shape[0]):
    #temp_VAD has 3 float numbers in it, returned from nlp_operations_VAD
    temp_VAD = nlp_operations_VAD(df1.iloc[idx, 0])
    #assigning Valence, Arousal, Dominance 
    df1.iloc[idx, 1] = temp_VAD[0]
    df1.iloc[idx, 2] = temp_VAD[1]
    df1.iloc[idx, 3] = temp_VAD[2]



df1.head(15)
# Out:
#                                                                                                                                      Twits  \
# 0                                                                                               7 bin kişilik gemide Korona virüsü şüphesi
# 1                                                                                               7 bin kişilik gemide Korona virüsü şüphesi
# 2        RT _ Dünya Sağlık Örgütü korona virüsü için acil durum ilan etti
#
# Korona Virüsü için alınan tedbirler araştırılsın önergesi AKP
# 3   RT _HelpDesk ℹ
# Korona Virüsü kaynaklı durumu ve son gelişmeleri ulusal ve uluslararası otoritelerle değerlendirmek için Pekin Guangzh
# 4                                                                             Çinde korona virüs vakası nedeniyle ölü sayısı 170e yükseldi
# 5           RT Dünya Sağlık Örgütü Corona virüsü nedeniyle uluslararası acil durum ilan ederken
#
# Birleşik Krallık ülkede Corona virüsün
# 6                              coronavirues coronavirus coronarovirus Korona Virüsü yayılımı ölü sayısına dair online harita oluşturuldu H
# 7                                                                                                                   Korona da içsinler inş
# 8             RT DİKKAT
# Bugün AKPMHP oylarıyla tedbirlerin alınmasının reddedildiği KORONA VİRÜSÜ için Dünya Sağlık Örgütü ALARM ilan ett
# 9             RT DİKKAT
# Bugün AKPMHP oylarıyla tedbirlerin alınmasının reddedildiği KORONA VİRÜSÜ için Dünya Sağlık Örgütü ALARM ilan ett
# 10           RT Korona Virüsü kaynaklı durumu ve son gelişmeleri ulusal ve uluslararası otoritelerle değerlendirmek için Pekin Guangzhou Ş
# 11                                                                                                  korona varken lassa nerden çıktı şimdi
# 12            RT DİKKAT
# Bugün AKPMHP oylarıyla tedbirlerin alınmasının reddedildiği KORONA VİRÜSÜ için Dünya Sağlık Örgütü ALARM ilan ett
# 13                         Sondakika sağlık örgütü çin hubei de 600 yeni korona virüsü vakası daha tespit etti bugün toplam 1800 kişi oldu
# 14                 RT THY ısrarla Çine yapılan seferleri durdurmuyor
#
# Mecliste korona virüsü için ulusal önlemlerin belirleneceği komisy
#
#    Valence Arousal Dominance
# 0     2.98    2.55      2.89
# 1     2.98    2.55      2.89
# 2     3.04    2.67      3.09
# 3     3.08     2.7       3.2
# 4      2.7    2.57      2.56
# 5     3.06    2.63      3.05
# 6      2.6    2.46      2.72
# 7     3.71    2.62      3.14
# 8     3.13    2.79      3.31
# 9     3.13    2.79      3.31
# 10    3.13    2.64      3.17
# 11    3.37    2.38      3.28
# 12    3.13    2.79      3.31
# 13    3.35    2.55      3.06
# 14    3.07    2.54      3.27

# %%
df1.to_csv("jan20_p.csv", header=True, sep=';', decimal='.')

# %%
#df1["Twits"] = df1['Twits'].str.replace(r"\\r|\\n|\\t", "", regex=True)
# Out:
# index:  0
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  rt
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['Rt']
# index:  1
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  dünya
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['Dünya', 'dünya']
# index:  2
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  sağlık
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['Sağlık', 'sağlık', 'sağ']
# index:  3
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  örgütü
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['örgüt']
# index:  4
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  corona
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['Corona']
# index:  5
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  virüsü
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['virüs']
# index:  6
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  nedeniyle
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['neden', 'nedeniyle']
# index:  7
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  uluslararası
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['uluslararası']
# index:  8
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  acil
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['acil']
# index:  9
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  durum
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['duru', 'durum']
# index:  10
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ilan
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['ilân']
# index:  11
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ederken
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['etmek', 'eder']
# index:  12
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  birleşik
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['birleşik']
# index:  13
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  krallık
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['kral', 'Krallık']
# index:  14
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ülkede
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['ülke', 'Ülke']
# index:  15
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  corona
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['Corona']
# index:  16
# t1 len: 17
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  virüsün
# [[('rt', ['Rt'])], [('dünya', ['Dünya', 'dünya'])], [('sağlık', ['Sağlık', 'sağlık', 'sağ'])], [('örgütü', ['örgüt'])], [('corona', ['Corona'])], [('virüsü', ['virüs'])], [('nedeniyle', ['neden', 'nedeniyle'])], [('uluslararası', ['uluslararası'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('ederken', ['etmek', 'eder'])], [('birleşik', ['birleşik'])], [('krallık', ['kral', 'Krallık'])], [('ülkede', ['ülke', 'Ülke'])], [('corona', ['Corona'])], [('virüsün', ['virüs'])]]
# words:  ['virüs']
# [3.06, 2.63, 3.05]

# %%
a1 = df1.iloc[5,0]
a1 = a1.replace(r"\r+|\n+|\t+", "", regex=True)
a1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-e538253a4f75> in <module>
#       1 a1 = df1.iloc[5,0]
# ----> 2 a1 = a1.str.replace(r"\r+|\n+|\t+", "", regex=True)
#       3 a1
#
# AttributeError: 'str' object has no attribute 'str'

# %%
# Out:
# [[('rt', ['Rt'])], [('_', ['_'])], [('dünya', ['dünya', 'Dünya'])], [('sağlık', ['sağ', 'sağlık', 'Sağlık'])], [('örgütü', ['örgüt'])], [('korona', ['koro'])], [('virüsü', ['virüs'])], [('için', ['için', 'içmek', 'iç'])], [('acil', ['acil'])], [('durum', ['duru', 'durum'])], [('ilan', ['ilân'])], [('etti', ['et', 'etmek'])], [('korona', ['koro'])], [('virüsü', ['virüs'])], [('için', ['için', 'içmek', 'iç'])], [('alınan', ['almak', 'alınmak'])], [('tedbirler', ['tedbir'])], [('araştırılsın', ['araştırmak'])], [('önergesi', ['önerge'])], [('akp', ['Akp'])]]
# [[('rt', ['Rt'])],
#  [('_', ['_'])],
#  [('dünya', ['dünya', 'Dünya'])],
#  [('sağlık', ['sağ', 'sağlık', 'Sağlık'])],
#  [('örgütü', ['örgüt'])],
#  [('korona', ['koro'])],
#  [('virüsü', ['virüs'])],
#  [('için', ['için', 'içmek', 'iç'])],
#  [('acil', ['acil'])],
#  [('durum', ['duru', 'durum'])],
#  [('ilan', ['ilân'])],
#  [('etti', ['et', 'etmek'])],
#  [('korona', ['koro'])],
#  [('virüsü', ['virüs'])],
#  [('için', ['için', 'içmek', 'iç'])],
#  [('alınan', ['almak', 'alınmak'])],
#  [('tedbirler', ['tedbir'])],
#  [('araştırılsın', ['araştırmak'])],
#  [('önergesi', ['önerge'])],
#  [('akp', ['Akp'])]]

# %%
# Out:
# <ipython-input-109-a06922ca3568>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test1df["Twits"] = test1df["Twits"].str.strip()
#                                                                                                                                     Twits  \
# 0                                                                                              7 bin kişilik gemide Korona virüsü şüphesi
# 1                                                                                              7 bin kişilik gemide Korona virüsü şüphesi
# 2       RT _ Dünya Sağlık Örgütü korona virüsü için acil durum ilan etti
#
# Korona Virüsü için alınan tedbirler araştırılsın önergesi AKP
# 3  RT _HelpDesk ℹ
# Korona Virüsü kaynaklı durumu ve son gelişmeleri ulusal ve uluslararası otoritelerle değerlendirmek için Pekin Guangzh
# 4                                                                            Çinde korona virüs vakası nedeniyle ölü sayısı 170e yükseldi
#
#   Valence Arousal Dominance
# 0    None    None      None
# 1    None    None      None
# 2    None    None      None
# 3    None    None      None
# 4    None    None      None

# %%
# Out:
#                                                                                                                                     Twits  \
# 0                                                                                              7 bin kişilik gemide Korona virüsü şüphesi
# 1                                                                                              7 bin kişilik gemide Korona virüsü şüphesi
# 2       RT _ Dünya Sağlık Örgütü korona virüsü için acil durum ilan etti
#
# Korona Virüsü için alınan tedbirler araştırılsın önergesi AKP
# 3  RT _HelpDesk ℹ
# Korona Virüsü kaynaklı durumu ve son gelişmeleri ulusal ve uluslararası otoritelerle değerlendirmek için Pekin Guangzh
# 4                                                                            Çinde korona virüs vakası nedeniyle ölü sayısı 170e yükseldi
#
#     Valence   Arousal Dominance
# 0  2.981667  2.550833  2.886667
# 1  2.981667  2.550833  2.886667
# 2  3.037692  2.669615  3.092692
# 3  3.081111  2.698333  3.202778
# 4  2.696667  2.570833  2.556667

# %%
"""
twit_jan20_DFT["Arousal"]=None
twit_jan20_DFT["Dominance"] = None

twit_jan20_DFT.head(5)
test1df.drop(test1df.columns[-1], axis=1, inplace=True)


#A piece of string
string1 = "abi selam naber"
#Lowercase it
string1 = string1.lower()
#Split it (or call it tokenizing)
split1 = [i for i in string1.split(' ')]

t1 = []
#This lemmatizes the words in the string
for i in range(len(split1)):
    t1.append(analyzer.lemmatize(split1[i]))
    
t1_V, t1_A, t1_D = [], [], []
#iterate over list that holds the lemmatized words
for i in range(len(t1)): #len(t1)
    #creating lists for valence, arousal and dominance values' mean, so that row of twit can have these values
    
    #iterate over lemmatization tuples
    for words in t1[i][0]:
        #Lemmas can be more than one so getting mean of interpretations could be useful.
        word_sum_V, word_sum_A, word_sum_D = [], [], []
        
        #Lemmtization products are in a list, take it by itself
        if type(words) == list:
            for i in words:
                if (anew_turkish["isimler"] == i).any():
                    word_sum_V.append(anew_turkish.loc[anew_turkish["isimler"] == i]["valence"].iloc[0])
                    word_sum_A.append(anew_turkish.loc[anew_turkish["isimler"] == i]["arousal"].iloc[0])
                    word_sum_D.append(anew_turkish.loc[anew_turkish["isimler"] == i]["dominance"].iloc[0])
   
        #Just string, which is the word without lemmazitaion
        elif type(words) == str:
            
            if (anew_turkish["isimler"] == i).any():
                word_sum_V.append(anew_turkish.loc[anew_turkish["isimler"] == i]["valence"].iloc[0])
                word_sum_A.append(anew_turkish.loc[anew_turkish["isimler"] == i]["arousal"].iloc[0])
                word_sum_D.append(anew_turkish.loc[anew_turkish["isimler"] == i]["dominance"].iloc[0])
        
        #Bunch up the words in mean to twit part.
        t1_V.append(get_mean(word_sum_V))
        t1_A.append(get_mean(word_sum_A))
        t1_D.append(get_mean(word_sum_D))

        
print(get_mean_twit(t1_V))
print(get_mean_twit(t1_A))
print(get_mean_twit(t1_D))

#print([get_mean_twit(t1_V), get_mean_twit(t1_A), get_mean_twit(t1_D)])
"""

#Removing stuff testing
"""
#Handles
abe = twit_jan20_DFT.iloc[3].astype("string")
print(abe)
abe = abe.str.replace('@[A-Za-z0-9]+', '')
print(abe)
#punctuation testing
abe = twit_jan20_DFT.iloc[3].astype("string")
print(abe)
abe = abe.str.replace('[^\w\s]+','')
print(abe)

#URLs
abe = twit_jan20_DFT.iloc[1].astype("string")
print(abe)
abe = abe.str.replace('http\S+','')
print(abe)

"""
"""
#Adding other columns
twit_jan20_DFT["Valence"] = None
twit_jan20_DFT["Arousal"]=None
twit_jan20_DFT["Dominance"] = None
"""
# Out:
# '\n#Adding other columns\ntwit_jan20_DFT["Valence"] = None\ntwit_jan20_DFT["Arousal"]=None\ntwit_jan20_DFT["Dominance"] = None\n'
